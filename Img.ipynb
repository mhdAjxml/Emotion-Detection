# %%
import cv2

# %%
from deepface import DeepFace
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from deepface import DeepFace
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\deepface\DeepFace.py:14
#      12 from tqdm import tqdm
#      13 import cv2
# ---> 14 import tensorflow as tf
#      16 # package dependencies
#      17 from deepface.basemodels import (
#      18     VGGFace,
#      19     OpenFace,
#    (...)
#      26     SFace,
#      27 )
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\__init__.py:38
#      35 import sys as _sys
#      36 import typing as _typing
# ---> 38 from tensorflow.python.tools import module_util as _module_util
#      39 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      41 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\__init__.py:45
#      43 from tensorflow.python import distribute
#      44 # from tensorflow.python import keras
# ---> 45 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      46 # from tensorflow.python.layers import layers
#      47 from tensorflow.python.module import module
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\feature_column\feature_column_lib.py:18
#      15 """FeatureColumns: tools for ingesting and representing features."""
#      17 # pylint: disable=unused-import,line-too-long,wildcard-import,g-bad-import-order
# ---> 18 from tensorflow.python.feature_column.feature_column import *
#      19 from tensorflow.python.feature_column.feature_column_v2 import *
#      20 from tensorflow.python.feature_column.sequence_feature_column import *
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\feature_column\feature_column.py:143
#     141 from tensorflow.python.framework import sparse_tensor as sparse_tensor_lib
#     142 from tensorflow.python.framework import tensor_shape
# --> 143 from tensorflow.python.layers import base
#     144 from tensorflow.python.ops import array_ops
#     145 from tensorflow.python.ops import check_ops
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\layers\base.py:16
#       1 # Copyright 2015 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # =============================================================================
#      15 """Contains the base Layer class, from which all layers inherit."""
# ---> 16 from tensorflow.python.keras.legacy_tf_layers import base
#      18 InputSpec = base.InputSpec
#      20 keras_style_scope = base.keras_style_scope
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\keras\__init__.py:22
#      20 # pylint: disable=unused-import
#      21 from tensorflow.python import tf2
# ---> 22 from tensorflow.python.keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
#      25 from tensorflow.python.keras import models
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\keras\distribute\__init__.py:18
#      15 """Keras' Distribution Strategy library."""
#      17 # pylint: disable=unused-import
# ---> 18 from tensorflow.python.keras.distribute import sidecar_evaluator
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\keras\distribute\sidecar_evaluator.py:23
#      21 from tensorflow.python.platform import tf_logging as logging
#      22 from tensorflow.python.training import checkpoint_utils
# ---> 23 from tensorflow.python.training.tracking import util as tracking_util
#      25 _PRINT_EVAL_STEP_EVERY_SEC = 60.0
#      26 _ITERATIONS_UNINITIALIZED = -1
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\training\tracking\util.py:55
#      53 from tensorflow.python.training.tracking import base
#      54 from tensorflow.python.training.tracking import data_structures
# ---> 55 from tensorflow.python.training.tracking import graph_view as graph_view_lib
#      56 from tensorflow.python.training.tracking import tracking
#      57 from tensorflow.python.util import compat
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\training\tracking\graph_view.py:25
#      23 from tensorflow.python.framework import ops
#      24 from tensorflow.python.saved_model import registration
# ---> 25 from tensorflow.python.training import optimizer as optimizer_v1
#      26 from tensorflow.python.training.saving import saveable_object as saveable_object_lib
#      27 from tensorflow.python.training.saving import saveable_object_util
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\training\optimizer.py:24
#      21 import six
#      23 from tensorflow.python.distribute import distribute_lib
# ---> 24 from tensorflow.python.distribute import distribute_utils
#      25 from tensorflow.python.distribute import distribution_strategy_context as distribute_ctx
#      26 from tensorflow.python.distribute import reduce_util as ds_reduce_util
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\distribute\distribute_utils.py:21
#      18 import contextlib
#      19 import threading
# ---> 21 from tensorflow.python.distribute import tpu_values as tpu_values_lib
#      22 from tensorflow.python.distribute import values as values_lib
#      23 from tensorflow.python.eager import context
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\distribute\tpu_values.py:22
#      15 """Various classes representing TPU distributed values.
#      16
#      17 Note that the tests are in values_test.py .
#      18
#      19 """
#      21 from tensorflow.python.distribute import packed_distributed_variable as packed
# ---> 22 from tensorflow.python.distribute import tpu_replicated_variable
#      23 from tensorflow.python.distribute import tpu_util
#      24 from tensorflow.python.distribute import values
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\distribute\tpu_replicated_variable.py:24
#      21 import contextlib
#      23 from tensorflow.compiler.xla.experimental.xla_sharding import xla_sharding
# ---> 24 from tensorflow.python.distribute import tpu_util
#      25 from tensorflow.python.eager import context
#      26 from tensorflow.python.framework import ops
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\distribute\tpu_util.py:22
#      20 from tensorflow.python.eager import context
#      21 from tensorflow.python.framework import ops
# ---> 22 from tensorflow.python.tpu import tpu
#      25 def enclosing_tpu_context():
#      26   """Returns the TPUReplicateContext, which exists inside a tpu.rewrite()."""
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\tpu\tpu.py:31
#      29 from tensorflow.core.protobuf.tpu import tpu_embedding_configuration_pb2 as embedding_pb2
#      30 from tensorflow.python import tf2
# ---> 31 from tensorflow.python.compiler.xla import xla
#      32 from tensorflow.python.distribute import device_util
#      33 from tensorflow.python.distribute import distribution_strategy_context
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\compiler\xla\__init__.py:19
#      17 # pylint: disable=unused-import
#      18 from tensorflow.python.compiler.xla import jit
# ---> 19 from tensorflow.python.compiler.xla import xla
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\python\compiler\xla\xla.py:20
#      15 """xla is an experimental library that provides XLA support APIs."""
#      17 import contextlib
# ---> 20 from tensorflow.compiler.jit.ops import xla_ops
#      21 from tensorflow.compiler.jit.ops import xla_ops_grad  # pylint: disable=unused-import
#      22 from tensorflow.core.framework import attr_value_pb2
#
# File ~\anaconda\envs\tensor_gpu\lib\site-packages\tensorflow\compiler\jit\ops\xla_ops.py:13
#      11 from tensorflow.python.eager import execute as _execute
#      12 from tensorflow.python.framework import dtypes as _dtypes
# ---> 13 from tensorflow.security.fuzzing.py import annotation_types as _atypes
#      15 from tensorflow.python.framework import op_def_registry as _op_def_registry
#      16 from tensorflow.python.framework import ops as _ops
#
# ModuleNotFoundError: No module named 'tensorflow.security'

# %%
img=cv2.imread("happyy.jpg")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
try:
  predictions= DeepFace.analyze(img)
except:
  print("No face detected")
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
predictions= DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 2.0526002231235907e-06,
#    'disgust': 3.93383772836946e-15,
#    'fear': 18.368545174598694,
#    'happy': 0.00020673796825576574,
#    'sad': 8.394365758057631e-09,
#    'surprise': 81.63124322891235,
#    'neutral': 1.3522152841893842e-08},
#   'dominant_emotion': 'surprise',
#   'region': {'x': 248, 'y': 72, 'w': 156, 'h': 156},
#   'age': 31,
#   'gender': {'Woman': 24.932129681110382, 'Man': 75.06787180900574},
#   'dominant_gender': 'Man',
#   'race': {'asian': 13.594222879065446,
#    'indian': 12.604203081381504,
#    'black': 12.129797764408455,
#    'white': 24.846008410811926,
#    'middle eastern': 14.444441464212028,
#    'latino hispanic': 22.381329380353055},
#   'dominant_race': 'white'}]

# %%
type(predictions)
# Out:
# list

# %%
print(predictions[0]['dominant_emotion'])
# Out:
# surprise

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces=faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,predictions[0]['dominant_emotion'],(0,50),font,1,(0,0,255),2,cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
