# %%
import cv2

# %%
from deepface import DeepFace

# %%
img=cv2.imread("happyy.jpg")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
try:
  predictions= DeepFace.analyze(img)
except:
  print("No face detected")
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  3.76it/s]

# %%
predictions= DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  4.98it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 2.0525951940329637e-06,
#    'disgust': 3.933828367548797e-15,
#    'fear': 18.368431530501336,
#    'happy': 0.00020673727571987374,
#    'sad': 8.394281603890177e-09,
#    'surprise': 81.63136134334572,
#    'neutral': 1.3522042625567927e-08},
#   'dominant_emotion': 'surprise',
#   'region': {'x': 248, 'y': 72, 'w': 156, 'h': 156},
#   'age': 31,
#   'gender': {'Woman': 24.932071566581726, 'Man': 75.06792545318604},
#   'dominant_gender': 'Man',
#   'race': {'asian': 13.594207298065102,
#    'indian': 12.604223204162503,
#    'black': 12.129826054552323,
#    'white': 24.8459622080281,
#    'middle eastern': 14.444434874586449,
#    'latino hispanic': 22.381345615547374},
#   'dominant_race': 'white'}]

# %%
type(predictions)
# Out:
# list

# %%
print(predictions[0]['dominant_emotion'])
# Out:
# surprise

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces=faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,predictions[0]['dominant_emotion'],(0,50),font,1,(0,0,255),2,cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
